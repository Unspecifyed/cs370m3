# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import RMSprop
import matplotlib.pyplot as plt
import scipy.ndimage  # Adding this line to check if ndimage is available

# Constants
IMG_CHANNELS = 3
IMG_ROWS = 32
IMG_COLS = 32
BATCH_SIZE = 128
NB_EPOCH = 50
NB_CLASSES = 10
VERBOSE = 1
VALIDATION_SPLIT = 0.2
OPTIM = RMSprop()

# Load dataset
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

# Convert to categorical
Y_train = to_categorical(y_train, NB_CLASSES)
Y_test = to_categorical(y_test, NB_CLASSES)

# Float and normalization
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255

# Data augmentation
datagen = ImageDataGenerator(
    featurewise_center=False, 
    samplewise_center=False, 
    featurewise_std_normalization=False, 
    samplewise_std_normalization=False, 
    zca_whitening=False, 
    rotation_range=15, 
    width_shift_range=0.1, 
    height_shift_range=0.1, 
    horizontal_flip=True, 
    vertical_flip=False)

datagen.fit(X_train)

# Network
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same', input_shape=(IMG_ROWS, IMG_COLS, IMG_CHANNELS)))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(NB_CLASSES))
model.add(Activation('softmax'))

model.summary()

# Compile model
model.compile(loss='categorical_crossentropy', optimizer=OPTIM, metrics=['accuracy'])

# Train model with data augmentation
history = model.fit(datagen.flow(X_train, Y_train, batch_size=BATCH_SIZE), 
                    epochs=NB_EPOCH, 
                    validation_data=(X_test, Y_test),
                    verbose=VERBOSE)

# Evaluate model
score = model.evaluate(X_test, Y_test, batch_size=BATCH_SIZE, verbose=VERBOSE)
print("Test score:", score[0])
print('Test accuracy:', score[1])

# Save model architecture and weights
model_json = model.to_json()
open('cifar10_architecture.json', 'w').write(model_json)
model.save_weights('cifar10_weights.h5', overwrite=True)

# Plot accuracy and loss
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.tight_layout()
plt.show()
# Out:
# X_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_12 (Conv2D)              │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_16 (Activation)      │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 30, 30, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_17 (Activation)      │ (None, 30, 30, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 15, 15, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_18 (Activation)      │ (None, 15, 15, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 13, 13, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_19 (Activation)      │ (None, 13, 13, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_16 (Conv2D)              │ (None, 6, 6, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_20 (Activation)      │ (None, 6, 6, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_17 (Conv2D)              │ (None, 4, 4, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_21 (Activation)      │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_22 (Activation)      │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │         5,130 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_23 (Activation)      │ (None, 10)             │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 554,794 (2.12 MB)
#  Trainable params: 554,794 (2.12 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 26s 63ms/step - accuracy: 0.1887 - loss: 2.1444 - val_accuracy: 0.3607 - val_loss: 1.7386
# Epoch 2/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 65ms/step - accuracy: 0.3836 - loss: 1.6794 - val_accuracy: 0.5052 - val_loss: 1.3990
# Epoch 3/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.4659 - loss: 1.4771 - val_accuracy: 0.5764 - val_loss: 1.1640
# Epoch 4/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.5216 - loss: 1.3395 - val_accuracy: 0.6020 - val_loss: 1.1076
# Epoch 5/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.5626 - loss: 1.2389 - val_accuracy: 0.5786 - val_loss: 1.2063
# Epoch 6/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.5918 - loss: 1.1549 - val_accuracy: 0.6531 - val_loss: 0.9837
# Epoch 7/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.6205 - loss: 1.0822 - val_accuracy: 0.6664 - val_loss: 0.9703
# Epoch 8/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.6401 - loss: 1.0274 - val_accuracy: 0.6957 - val_loss: 0.8752
# Epoch 9/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.6541 - loss: 0.9992 - val_accuracy: 0.6886 - val_loss: 0.9331
# Epoch 10/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.6659 - loss: 0.9629 - val_accuracy: 0.7091 - val_loss: 0.8576
# Epoch 11/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.6817 - loss: 0.9140 - val_accuracy: 0.7251 - val_loss: 0.8055
# Epoch 12/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.6876 - loss: 0.9017 - val_accuracy: 0.7501 - val_loss: 0.7437
# Epoch 13/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.7019 - loss: 0.8714 - val_accuracy: 0.7122 - val_loss: 0.8952
# Epoch 14/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.7059 - loss: 0.8574 - val_accuracy: 0.7469 - val_loss: 0.7611
# Epoch 15/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.7154 - loss: 0.8284 - val_accuracy: 0.7428 - val_loss: 0.7696
# Epoch 16/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.7197 - loss: 0.8142 - val_accuracy: 0.7326 - val_loss: 0.8524
# Epoch 17/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.7271 - loss: 0.8034 - val_accuracy: 0.7058 - val_loss: 1.0032
# Epoch 18/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.7267 - loss: 0.8079 - val_accuracy: 0.7562 - val_loss: 0.7338
# Epoch 19/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 65ms/step - accuracy: 0.7301 - loss: 0.7861 - val_accuracy: 0.7660 - val_loss: 0.7004
# Epoch 20/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.7391 - loss: 0.7716 - val_accuracy: 0.7319 - val_loss: 0.8272
# Epoch 21/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.7401 - loss: 0.7667 - val_accuracy: 0.7501 - val_loss: 0.8097
# Epoch 22/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.7444 - loss: 0.7574 - val_accuracy: 0.7890 - val_loss: 0.6421
# Epoch 23/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.7451 - loss: 0.7522 - val_accuracy: 0.7739 - val_loss: 0.6895
# Epoch 24/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.7469 - loss: 0.7578 - val_accuracy: 0.7560 - val_loss: 0.7147
# Epoch 25/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.7530 - loss: 0.7485 - val_accuracy: 0.7694 - val_loss: 0.7386
# Epoch 26/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.7499 - loss: 0.7479 - val_accuracy: 0.7397 - val_loss: 0.8391
# Epoch 27/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.7505 - loss: 0.7485 - val_accuracy: 0.7968 - val_loss: 0.6231
# Epoch 28/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.7507 - loss: 0.7475 - val_accuracy: 0.7563 - val_loss: 0.7237
# Epoch 29/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.7480 - loss: 0.7516 - val_accuracy: 0.7892 - val_loss: 0.6508
# Epoch 30/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.7525 - loss: 0.7375 - val_accuracy: 0.7700 - val_loss: 0.7357
# Epoch 31/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.7519 - loss: 0.7456 - val_accuracy: 0.7802 - val_loss: 0.6771
# Epoch 32/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.7547 - loss: 0.7439 - val_accuracy: 0.7679 - val_loss: 0.7108
# Epoch 33/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.7650 - loss: 0.7160 - val_accuracy: 0.7258 - val_loss: 0.8695
# Epoch 34/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.7587 - loss: 0.7292 - val_accuracy: 0.7521 - val_loss: 0.8007
# Epoch 35/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.7566 - loss: 0.7417 - val_accuracy: 0.7906 - val_loss: 0.6447
# Epoch 36/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.7557 - loss: 0.7300 - val_accuracy: 0.7892 - val_loss: 0.6576
# Epoch 37/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.7564 - loss: 0.7302 - val_accuracy: 0.7658 - val_loss: 0.7442
# Epoch 38/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.7607 - loss: 0.7297 - val_accuracy: 0.8085 - val_loss: 0.5967
# Epoch 39/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.7589 - loss: 0.7276 - val_accuracy: 0.7854 - val_loss: 0.6983
# Epoch 40/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.7636 - loss: 0.7257 - val_accuracy: 0.7551 - val_loss: 0.7704
# Epoch 41/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.7637 - loss: 0.7170 - val_accuracy: 0.7890 - val_loss: 0.6560
# Epoch 42/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.7602 - loss: 0.7208 - val_accuracy: 0.7931 - val_loss: 0.6385
# Epoch 43/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.7619 - loss: 0.7213 - val_accuracy: 0.7574 - val_loss: 0.7456
# Epoch 44/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.7604 - loss: 0.7265 - val_accuracy: 0.7673 - val_loss: 0.7314
# Epoch 45/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.7651 - loss: 0.7175 - val_accuracy: 0.7792 - val_loss: 0.6774
# Epoch 46/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.7637 - loss: 0.7246 - val_accuracy: 0.8112 - val_loss: 0.5940
# Epoch 47/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.7671 - loss: 0.7051 - val_accuracy: 0.8052 - val_loss: 0.6164
# Epoch 48/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.7603 - loss: 0.7286 - val_accuracy: 0.7928 - val_loss: 0.6639
# Epoch 49/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.7606 - loss: 0.7247 - val_accuracy: 0.7938 - val_loss: 0.6539
# Epoch 50/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 64ms/step - accuracy: 0.7621 - loss: 0.7343 - val_accuracy: 0.7707 - val_loss: 0.7206
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7719 - loss: 0.7207
# Test score: 0.7205609679222107
# Test accuracy: 0.7706999778747559
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_10151/204172614.py in <module>
#     103 model_json = model.to_json()
#     104 open('cifar10_architecture.json', 'w').write(model_json)
# --> 105 model.save_weights('cifar10_weights.h5', overwrite=True)
#     106
#     107 # Plot accuracy and loss
#
# ~/.local/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# ~/.local/lib/python3.10/site-packages/keras/src/saving/saving_api.py in save_weights(model, filepath, overwrite, **kwargs)
#     215 def save_weights(model, filepath, overwrite=True, **kwargs):
#     216     if not str(filepath).endswith(".weights.h5"):
# --> 217         raise ValueError(
#     218             "The filename must end in `.weights.h5`. "
#     219             f"Received: filepath={filepath}"
#
# ValueError: The filename must end in `.weights.h5`. Received: filepath=cifar10_weights.h5
